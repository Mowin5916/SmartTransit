# %%
import pandas as pd

# -------------------------------
# STEP 1 — Load all datasets
# -------------------------------
weather = pd.read_csv("../data/bangalore_weather_clean.csv")
passenger = pd.read_csv("../data/passenger_demand.csv")
traffic = pd.read_csv("../data/traffic_data.csv")

print("✅ Files loaded successfully!")

# -------------------------------
# STEP 2 — Preprocess: ensure consistent column names
# -------------------------------
# Convert date columns to proper datetime format
weather['Date'] = pd.to_datetime(weather[['Year', 'Month', 'Day']])
passenger['Date'] = pd.to_datetime(passenger['Date'])
traffic['Date'] = pd.to_datetime(traffic['Date'])

# Clean up column names
passenger.rename(columns={'Weather': 'Weather_Condition'}, inplace=True)

# -------------------------------
# STEP 3 — Merge datasets
# -------------------------------
# Merge passenger and weather data (on Date)
merged_pw = pd.merge(passenger, weather,
                     how='left',
                     on='Date')

# Merge the traffic data (on Date and Time_Slot)
merged_final = pd.merge(merged_pw, traffic,
                        how='left',
                        on=['Date', 'Time_Slot'])

# -------------------------------
# STEP 4 — Save final dataset
# -------------------------------
merged_final.to_csv("../data/merged_transit_data.csv", index=False)

print("✅ merged_transit_data.csv created successfully!")
print(f"Rows: {len(merged_final)}")
print("📊 Columns:", list(merged_final.columns))
print("\nSample preview:")
print(merged_final.head(10))
# Out:
# ✅ Files loaded successfully!
# ✅ merged_transit_data.csv created successfully!
# Rows: 1200
# 📊 Columns: ['Date', 'Route_ID', 'Route_Name', 'Time_Slot', 'Weather_Condition', 'Temperature_C_x', 'Rainfall_mm_x', 'Passenger_Count', 'Year', 'Month', 'Day', 'Hour', 'Rainfall_mm_y', 'SolarRadiation_Wm2', 'Temperature_C_y', 'WindSpeed_mps', 'WindDirection_deg', 'Live_Congestion_Level(%)', 'Usual_Congestion_Level(%)', 'Live_Speed_kmph', 'Delay_Minutes_per_10km', 'Accident_Risk_Level']
#
# Sample preview:
#         Date Route_ID              Route_Name  Time_Slot Weather_Condition  \
# 0 2025-01-01       R1  Majestic to Whitefield    Morning            Cloudy
# 1 2025-01-01       R1  Majestic to Whitefield  Afternoon             Foggy
# 2 2025-01-01       R1  Majestic to Whitefield    Evening             Sunny
# 3 2025-01-01       R1  Majestic to Whitefield      Night             Sunny
# 4 2025-01-01       R2         Majestic to BTM    Morning             Rainy
# 5 2025-01-01       R2         Majestic to BTM  Afternoon             Rainy
# 6 2025-01-01       R2         Majestic to BTM    Evening             Sunny
# 7 2025-01-01       R2         Majestic to BTM      Night             Sunny
# 8 2025-01-01       R3    Silk Board to Hebbal    Morning             Foggy
# 9 2025-01-01       R3    Silk Board to Hebbal  Afternoon            Cloudy
#
#    Temperature_C_x  Rainfall_mm_x  Passenger_Count  Year  Month  ...  \
# 0             20.9            0.0              181   NaN    NaN  ...
# 1             24.0            0.0              148   NaN    NaN  ...
# 2             28.6            0.0              176   NaN    NaN  ...
# 3             27.5            0.0               58   NaN    NaN  ...
# 4             20.9            8.1              109   NaN    NaN  ...
# 5             22.3            4.7               48   NaN    NaN  ...
# 6             24.1            0.0               44   NaN    NaN  ...
# 7             31.1            0.0               41   NaN    NaN  ...
# 8             22.0            0.0              199   NaN    NaN  ...
# 9             29.8            0.0              125   NaN    NaN  ...
#
#    Rainfall_mm_y  SolarRadiation_Wm2  Temperature_C_y  WindSpeed_mps  \
# 0            NaN                 NaN              NaN            NaN
# 1            NaN                 NaN              NaN            NaN
# 2            NaN                 NaN              NaN            NaN
# 3            NaN                 NaN              NaN            NaN
# 4            NaN                 NaN              NaN            NaN
# 5            NaN                 NaN              NaN            NaN
# 6            NaN                 NaN              NaN            NaN
# 7            NaN                 NaN              NaN            NaN
# 8            NaN                 NaN              NaN            NaN
# 9            NaN                 NaN              NaN            NaN
#
#    WindDirection_deg  Live_Congestion_Level(%)  Usual_Congestion_Level(%)  \
# 0                NaN                       NaN                        NaN
# 1                NaN                       NaN                        NaN
# 2                NaN                       NaN                        NaN
# 3                NaN                       NaN                        NaN
# 4                NaN                       NaN                        NaN
# 5                NaN                       NaN                        NaN
# 6                NaN                       NaN                        NaN
# 7                NaN                       NaN                        NaN
# 8                NaN                       NaN                        NaN
# 9                NaN                       NaN                        NaN
#
#    Live_Speed_kmph  Delay_Minutes_per_10km  Accident_Risk_Level
# 0              NaN                     NaN                  NaN
# 1              NaN                     NaN                  NaN
# 2              NaN                     NaN                  NaN
# 3              NaN                     NaN                  NaN
# 4              NaN                     NaN                  NaN
# 5              NaN                     NaN                  NaN
# 6              NaN                     NaN                  NaN
# 7              NaN                     NaN                  NaN
# 8              NaN                     NaN                  NaN
# 9              NaN                     NaN                  NaN
#
# [10 rows x 22 columns]
